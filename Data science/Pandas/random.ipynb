# %% [markdown]
# ## numpy의 np.random. randint vs rand/randn

# %%
import numpy as np

# %% [markdown]
# ### random.randint 와 np.random.randint: 모두 (시작, n-1)사이의 랜덤숫자 1개 뽑아내기

# %%
np.random.randint(6) # 0 or 1 or ~ or 5 0부터 5까지 랜덤한 숫자 1개
# Out:
# 5

# %%
np.random.randint(1, 20) # 1부터 19까지 랜덤숫자 1개
# Out:
# 1

# %% [markdown]
# ### np.random.rand(m, n): 0~1의 균일분포 표준정규분포 난수를 matrix array(m, n) 생성

# %%
np.random.rand(6)
# Out:
# array([0.85868519, 0.482928  , 0.77046599, 0.55806735, 0.5556504 ,
#        0.44844686])

# %%
np.random.rand(3, 2)
# Out:
# array([[0.67853101, 0.91261452],
#        [0.13383638, 0.98593526],
#        [0.53658162, 0.54891457]])

# %% [markdown]
# ### np.random.randn(m, n): 평균0, 표준편차1의 가우시안 표준정규분포 난수를 matrix array(m, n) 생성

# %%
np.random.randn(6)
# Out:
# array([-1.60904294, -1.44775654, -0.51251945,  0.55278743,  1.16012706,
#        -0.64197999])

# %%
np.random.randn(3, 2)
# Out:
# array([[-0.82345261, -0.99082112],
#        [-0.89482928,  0.585453  ],
#        [ 0.39160042,  0.2839424 ]])
